# %% [markdown]
# # XRD Code

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %% [markdown]
# ## Test Run CsCl

# %%
with open('/Users/guneraygin/Documents/University/Y3 Labs/X-Ray Diffraction/Raw XRD Data/Initial scan CsCl.txt') as f:
    lines = f.readlines()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/f6/ysbvf32j6ks_1h83gmlfzghw0000gn/T/ipykernel_9774/852083056.py in <module>
# ----> 1 with open('/Users/guneraygin/Documents/University/Y3 Labs/X-Ray Diffraction/Raw XRD Data/Initial scan CsCl.txt') as f:
#       2     lines = f.readlines()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/guneraygin/Documents/University/Y3 Labs/X-Ray Diffraction/Raw XRD Data/Initial scan CsCl.txt'

# %%
lines = [line.replace(" ", '') for line in lines]
lines = [line.replace('\n','') for line in lines]
lines = [line.strip(',') for line in lines]
data = [line.split(',') for line in lines]

# %%
data = np.array(data)
data = data.astype(float)

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(data[:,0],data[:,1], color='green')
plt.title('Trial run XRD graph for CsCl', size=20)
plt.xlabel('$2\Theta$ [degrees]',size=15)
plt.ylabel('Intensity',size=15)
plt.xticks(size=14)
plt.yticks(size=13)
#plt.savefig('Trial run CsCl.png')
plt.show()

# %% [markdown]
# Intensity is usually normalised such that $I_{max}$ = 100.

# %%
N = 1/np.max(data[:,1]) * 100

fig = plt.figure(figsize=(12,8))
plt.plot(data[:,0],N*data[:,1], color='green')
plt.title('Normalised trial run XRD graph for CsCl', size=20)
plt.xlabel(r'$2\theta$ [degrees]',size=18)
plt.ylabel(r'$\frac{I}{I_{1}}$',size=30,rotation=0)
plt.xticks(size=14)
plt.yticks(size=13)
#plt.savefig('normalised trial run CsCl.png')
plt.show()

# %% [markdown]
# ## CsCl

# %%
with open('/Users/guneraygin/Desktop/Y3 Labs/X-Ray Diffraction/Raw XRD Data/CsCl 0.1 step 2 sec.txt') as f:
    lines = f.readlines()
    
lines = [line.replace(" ", '') for line in lines]
lines = [line.replace('\n','') for line in lines]
lines = [line.strip(',') for line in lines]
data = [line.split(',') for line in lines]

data = np.array(data)
data_cs = data.astype(float)

N_cs = 1/np.max(data_cs[:,1]) * 100

fig = plt.figure(figsize=(12,8))
plt.plot(data_cs[:,0],N*data_cs[:,1], color='red')
plt.title('CsCl XRD', size=20)
plt.xlabel(r'$2\theta$ [degrees]',size=18)
plt.ylabel(r'$\frac{I}{I_{1}}$',size=30,rotation=0)
plt.xticks(size=14)
plt.yticks(size=13)
#plt.savefig('CsCl graph (20-120).png')
plt.show()

# %%
with open('/Users/guneraygin/Desktop/Y3 Labs/X-Ray Diffraction/Raw XRD Data/CsCl 0.1 step 2 sec.txt') as f:
    lines = f.readlines()
    
with open('/Users/guneraygin/Desktop/Y3 Labs/X-Ray Diffraction/Raw XRD Data/10-20 degrees.txt') as f2:
    lines2 = f2.readlines()

lines = [line.replace(" ", '') for line in lines]
lines = [line.replace('\n','') for line in lines]
lines = [line.strip(',') for line in lines]
data = [line.split(',') for line in lines]

lines2 = [line.replace(" ", '') for line in lines2]
lines2 = [line.replace('\n','') for line in lines2]
lines2 = [line.strip(',') for line in lines2]
data2 = [line.split(',') for line in lines2]

data = np.array(data)
data = data.astype(float)

data2 = np.array(data2)
data2 = data2.astype(float)

N = 1/np.max(data[:,1]) * 100

fig = plt.figure(figsize=(12,8))
plt.plot(data[:,0],N*data[:,1], color='red')
plt.plot(data2[:,0],N*data2[:,1], color='red')
plt.title('CsCl XRD', size=20)
plt.xlabel(r'$2\theta$ [degrees]',size=18)
plt.ylabel(r'$\frac{I}{I_{1}}$',size=30,rotation=0)
plt.xticks(size=14)
plt.yticks(size=13)
plt.xlim(50,57)
plt.ylim(0,4)
#plt.savefig('CsCl graph.png')
plt.show()

print(f'Turning point between 10 and 20 degrees occurs at {data2[np.argmin(data2[:,1]),0]}')

# %%
x = list(data[:,0])
y = N*data[:,1]

y[x.index(119.5)]

# %%
A = 0.1255/2

lamd = 1.5418

np.sqrt(5*A*lamd**2/4)

# %% [markdown]
# Plotted with data between 10-20 degrees as well, to see if there were any additional peaks. As you can see from the graph, no peaks detected, and curve is continuous.

# %% [markdown]
# ## NaCl

# %%
with open('/Users/guneraygin/Desktop/Y3 Labs/X-Ray Diffraction/Raw XRD Data/NaCl 0.1 step 2 sec.txt') as f:
    lines = f.readlines()

lines = [line.replace(" ", '') for line in lines]
lines = [line.replace('\n','') for line in lines]
lines = [line.strip(',') for line in lines]
data = [line.split(',') for line in lines]

data = np.array(data)
data_NaCl = data.astype(float)

N_NaCl = 1/np.max(data_NaCl[:,1]) * 100

fig = plt.figure(figsize=(12,8))
plt.plot(data_NaCl[:,0],N_NaCl*data_NaCl[:,1], color='red')
plt.title('NaCl XRD', size=20)
plt.xlabel(r'$2\theta$ [degrees]',size=18)
plt.ylabel(r'$\frac{I}{I_{1}}$',size=30,rotation=0)
plt.xticks(size=14)
plt.yticks(size=13)
#plt.savefig('NaCl graph.png')
plt.show()

print(np.max(data_NaCl[:,1]))

# %%
''' Better NaCl XRD'''

with open('/Users/guneraygin/Desktop/Y3 Labs/X-Ray Diffraction/Raw XRD Data/NaCl ground up.txt') as f:
    lines = f.readlines()

lines = [line.replace(" ", '') for line in lines]
lines = [line.replace('\n','') for line in lines]
lines = [line.strip(',') for line in lines]
data = [line.split(',') for line in lines]

data = np.array(data)
data_NaCl = data.astype(float)

N_NaCl = 1/np.max(data_NaCl[:,1]) * 100

fig = plt.figure(figsize=(12,8))
plt.plot(data_NaCl[:,0]-0.3,N_NaCl*data_NaCl[:,1], color='red')
plt.title('NaCl XRD', size=20)
plt.xlabel(r'$2\theta$ [degrees]',size=18)
plt.ylabel(r'$\frac{I}{I_{1}}$',size=30,rotation=0)
plt.xticks(size=14)
plt.yticks(size=13)
#plt.savefig('Better NaCl graph.png')
plt.show()

print(np.max(data_NaCl[:,1]))

# %% [markdown]
# ## Is CsCl actually NaCl

# %%
''' Superposition of NaCl and Fake CsCl XRD'''

fig = plt.figure(figsize=(15,10))
plt.plot(data_cs[:,0],N_cs*data_cs[:,1], color='red', label='Not CsCl',)
plt.plot(data_NaCl[:,0]-0.3,N_NaCl*data_NaCl[:,1], color='blue', label='NaCl', linestyle='dotted')
plt.title("NaCl vs 'CsCl' XRD", size=20)
plt.xlabel(r'$2\theta$ [degrees]',size=18)
plt.ylabel(r'$\frac{I}{I_{1}}$',size=30,rotation=0)
plt.xticks(size=14)
plt.yticks(size=13)
plt.xlim(20,100)
plt.legend(loc = 'best', prop={'size':15})
#plt.savefig('CsCl vs NaCl plot.png')
plt.show()

# %% [markdown]
# ## NaCl + KCl

# %%
with open('/Users/guneraygin/Desktop/Y3 Labs/X-Ray Diffraction/Raw XRD Data/NaCl KCl 0.1 step 2 sec.txt') as f:
    lines = f.readlines()

lines = [line.replace(" ", '') for line in lines]
lines = [line.replace('\n','') for line in lines]
lines = [line.strip(',') for line in lines]
data = [line.split(',') for line in lines]

data = np.array(data)
data_lowsodium = data.astype(float)

N_lowsodium = 1/np.max(data_lowsodium[:,1]) * 100

fig = plt.figure(figsize=(12,8))
plt.plot(data_lowsodium[:,0],N_lowsodium*data_lowsodium[:,1], color='red', label='NaCl + KCl')
plt.title("'Low Sodium' XRD", size=20)
plt.xlabel(r'$2\theta$ [degrees]',size=18)
plt.ylabel(r'$\frac{I}{I_{1}}$',size=30,rotation=0)
plt.xticks(size=14)
plt.yticks(size=13)

'''  placing text in a graph'''
plt.text(30, 101, 'hello', fontdict=None)

#plt.savefig('NaCl + KCl graph.png')
plt.show()

print(np.max(data_lowsodium[:,1]))
print(np.max(data_NaCl[:,1]))

print('Note that the two Maxima (and hence normalisation factors) are not equal.')

# %%
''' Superposition of Pure Sodium and Sodium w/ Potassium XRD'''

fig = plt.figure(figsize=(12,8))
plt.plot(data_cs[:,0],N_cs*data_cs[:,1], color='red', label='NaCl + KCl',)
plt.plot(data_NaCl[:,0][0:811],N_NaCl*data_NaCl[:,1][0:811], color='blue', label='NaCl', linestyle='dotted')
plt.title('Sodium and Low Sodium XRD', size=20)
plt.xlabel(r'$2\theta$ [degrees]',size=18)
plt.ylabel(r'$\frac{I}{I_{1}}$',size=30,rotation=0)
plt.xticks(size=14)
plt.yticks(size=13)
plt.legend(loc = 'best', prop={'size':15})
plt.savefig('salt difference plot.png')
plt.show()

# %% [markdown]
# ## Difference between NaCl plot and NaCl + KCl plot

# %%
''' Superposition of Pure Sodium and Sodium w/ Potassium XRD'''

fig = plt.figure(figsize=(14,10))
plt.plot(data_lowsodium[:,0],N_lowsodium*data_lowsodium[:,1], color='red', label='NaCl + KCl',)
plt.plot(data_NaCl[:,0][0:811]-0.3,N_NaCl*data_NaCl[:,1][0:811], color='blue', label='NaCl', linestyle='dotted')
plt.title('Sodium and Low Sodium XRD', size=20)
plt.xlabel(r'$2\theta$ [degrees]',size=18)
plt.ylabel(r'$\frac{I}{I_{1}}$',size=30,rotation=0)
plt.xticks(size=14)
plt.yticks(size=13)
plt.legend(loc = 'best', prop={'size':15})
#plt.savefig('salt difference plot.png')
plt.show()

# %% [markdown]
# Clear KCl peak at 40 and 50 degrees, and possibly near 60, 74, 28.

# %%
''' This graph is a work in progress, and is by no means finished '''

data_difference = (N_lowsodium*data_lowsodium[:,1][0:801] - N_NaCl*data_NaCl[:,1][0:801])


fig = plt.figure(figsize=(12,8))
plt.plot(data_NaCl[:,0][0:801]-0.3,data_difference, color='red')
plt.title('(NaCl + KCl) - NaCl XRD', size=20)
plt.xlabel(r'$2\theta$ [degrees]',size=18)
plt.ylabel(r'$\frac{I}{I_{1}}$',size=30,rotation=0)
plt.xticks(size=14)
plt.yticks(size=13)
plt.show()

# %% [markdown]
# ## Rhodochrosite

# %%
with open('/Users/guneraygin/Desktop/Y3 Labs/X-Ray Diffraction/Raw XRD Data/Unknown Crystal.txt') as f:
    lines = f.readlines()

lines = [line.replace(" ", '') for line in lines]
lines = [line.replace('\n','') for line in lines]
lines = [line.strip(',') for line in lines]
data = [line.split(',') for line in lines]

data = np.array(data)
data = data.astype(float)

N = 1/np.max(data[:,1]) * 100

fig = plt.figure(figsize=(12,8))
plt.plot(data[:,0],N*data[:,1], color='magenta')
plt.title('Unknown Mineral XRD', size=20)
plt.xlabel(r'$2\theta$ [degrees]',size=18)
plt.ylabel(r'$\frac{I}{I_{1}}$',size=30,rotation=0)
plt.xticks(size=14)
plt.yticks(size=13)
#plt.savefig('Rhodochrosite graph.png')
plt.show()

# %% [markdown]
# ## Sugar

# %%
with open('/Users/guneraygin/Desktop/Y3 Labs/X-Ray Diffraction/Raw XRD Data/Sugar.txt') as f:
    lines = f.readlines()

lines = [line.replace(" ", '') for line in lines]
lines = [line.replace('\n','') for line in lines]
lines = [line.strip(',') for line in lines]
data = [line.split(',') for line in lines]

data = np.array(data)
data = data.astype(float)

N = 1/np.max(data[:,1]) * 100

fig = plt.figure(figsize=(12,8))
plt.plot(data[:,0],N*data[:,1], color='red')
plt.title(r'$C_{12}H_{22}O_{11}$ XRD', size=20)
plt.xlabel(r'$2\theta$ [degrees]',size=18)
plt.ylabel(r'$\frac{I}{I_{1}}$',size=30,rotation=0)
plt.xticks(size=14)
plt.yticks(size=13)
#plt.savefig('sugar.png')
plt.show()

# %%
with open('/Users/guneraygin/Desktop/Y3 Labs/X-Ray Diffraction/Raw XRD Data/Sugar 0.05.txt') as f:
    lines = f.readlines()

lines = [line.replace(" ", '') for line in lines]
lines = [line.replace('\n','') for line in lines]
lines = [line.strip(',') for line in lines]
data = [line.split(',') for line in lines]

data = np.array(data)
data = data.astype(float)

N = 1/np.max(data[:,1]) * 100

fig = plt.figure(figsize=(12,8))
plt.plot(data[:,0],N*data[:,1], color='red')
plt.title(r'$C_{12}H_{22}O_{11}$ XRD', size=20)
plt.xlabel(r'$2\theta$ [degrees]',size=18)
plt.ylabel(r'$\frac{I}{I_{1}}$',size=30,rotation=0)
plt.xticks(size=14)
plt.yticks(size=13)
#plt.savefig('sugar short.png')
plt.show()

# %% [markdown]
# ## Putting different filters inside of the XRD Machine

# %%
################################################################################################################
with open('/Users/guneraygin/Desktop/Y3 Labs/X-Ray Diffraction/Raw XRD Data/Filter Data/2 1 0.1.txt') as f:
    lines = f.readlines()

lines = [line.replace(" ", '') for line in lines]
lines = [line.replace('\n','') for line in lines]
lines = [line.strip(',') for line in lines]
data = [line.split(',') for line in lines]

data = np.array(data)
data1 = data.astype(float)
N1 = 1/np.max(data1[:,1]) * 100
################################################################################################################
################################################################################################################
with open('/Users/guneraygin/Desktop/Y3 Labs/X-Ray Diffraction/Raw XRD Data/Filter Data/2 1 0.2.txt') as f:
    lines = f.readlines()

lines = [line.replace(" ", '') for line in lines]
lines = [line.replace('\n','') for line in lines]
lines = [line.strip(',') for line in lines]
data = [line.split(',') for line in lines]

data = np.array(data)
data2 = data.astype(float)
N2 = 1/np.max(data2[:,1]) * 100
################################################################################################################
################################################################################################################
with open('/Users/guneraygin/Desktop/Y3 Labs/X-Ray Diffraction/Raw XRD Data/Filter Data/2 1 0.6.txt') as f:
    lines = f.readlines()

lines = [line.replace(" ", '') for line in lines]
lines = [line.replace('\n','') for line in lines]
lines = [line.strip(',') for line in lines]
data = [line.split(',') for line in lines]

data = np.array(data)
data3 = data.astype(float)
N3 = 1/np.max(data3[:,1]) * 100
################################################################################################################
################################################################################################################
with open('/Users/guneraygin/Desktop/Y3 Labs/X-Ray Diffraction/Raw XRD Data/Filter Data/2 1 1.txt') as f:
    lines = f.readlines()

lines = [line.replace(" ", '') for line in lines]
lines = [line.replace('\n','') for line in lines]
lines = [line.strip(',') for line in lines]
data = [line.split(',') for line in lines]

data = np.array(data)
data4 = data.astype(float)
N4 = 1/np.max(data4[:,1]) * 100
################################################################################################################
################################################################################################################
with open('/Users/guneraygin/Desktop/Y3 Labs/X-Ray Diffraction/Raw XRD Data/Filter Data/2 1 2.txt') as f:
    lines = f.readlines()

lines = [line.replace(" ", '') for line in lines]
lines = [line.replace('\n','') for line in lines]
lines = [line.strip(',') for line in lines]
data = [line.split(',') for line in lines]

data = np.array(data)
data5 = data.astype(float)
N5 = 1/np.max(data5[:,1]) * 100
################################################################################################################
################################################################################################################
with open('/Users/guneraygin/Desktop/Y3 Labs/X-Ray Diffraction/Raw XRD Data/Filter Data/2 1 6.txt') as f:
    lines = f.readlines()

lines = [line.replace(" ", '') for line in lines]
lines = [line.replace('\n','') for line in lines]
lines = [line.strip(',') for line in lines]
data = [line.split(',') for line in lines]

data = np.array(data)
data6 = data.astype(float)
N6 = 1/np.max(data6[:,1]) * 100
################################################################################################################
################################################################################################################
with open('/Users/guneraygin/Desktop/Y3 Labs/X-Ray Diffraction/Raw XRD Data/Filter Data/2 2 0.2.txt') as f:
    lines = f.readlines()

lines = [line.replace(" ", '') for line in lines]
lines = [line.replace('\n','') for line in lines]
lines = [line.strip(',') for line in lines]
data = [line.split(',') for line in lines]

data = np.array(data)
data7 = data.astype(float)
N7 = 1/np.max(data7[:,1]) * 100
################################################################################################################

fig = plt.figure(figsize=(18,12))
plt.plot(data1[:,0],N1*data1[:,1], color='red', label='1mm, 0.1mm')
plt.plot(data2[:,0],N2*data2[:,1], color='orange', label='1mm, 0.2mm')
plt.plot(data7[:,0],N7*data7[:,1], color='green', label='2mm, 0.2mm')
plt.plot(data3[:,0],N3*data3[:,1], color='blue', label='1mm, 0.6mm')
plt.plot(data4[:,0],N4*data4[:,1], color='darkblue', label='1mm, 1mm')
plt.plot(data5[:,0],N5*data5[:,1], color='mediumorchid',label='1mm, 2mm')
plt.plot(data6[:,0],N6*data6[:,1], color='magenta', label='1mm, 6mm')
plt.title('Individually Normalised NaCl XRD using different slits', size=20)
plt.xlabel(r'$2\theta$ [degrees]',size=18)
plt.ylabel(r'$\frac{I}{I_{1}}$',size=30,rotation=0)
plt.xticks(size=14)
plt.yticks(size=13)
plt.xlim(31.1,32.4)
plt.legend(loc = 'upper left', prop={'size':15})
#plt.savefig('different filters XRD.png')
plt.show()

# %%
half_width1 = (0.28583003-0.28528988)/N1
half_width2 = (0.16096376-0.16053635)/N2
half_width3 = np.abs((8.487e-2 - 8.53998926e-2)/N3)
half_width4 = (7.830510974e-2 - 7.76169292e-2)/N4
half_width5 = (7.00529610e-2 - 6.88930713e-2)/N5
half_width6 = (6.40370584e-2 - 6.22875206e-2)/N6
half_width7 = (0.11442249 - 0.11397)/N7

half_width_list = [half_width1, half_width2, half_width3, half_width4, half_width5, half_width6]
slit_list = [0.1, 0.2, 0.6, 1, 2, 6]
errors = 0.01*np.ones(6)

fig = plt.figure(figsize=(12,8))
plt.errorbar(slit_list, half_width_list, yerr = errors, fmt='.', color ='blue')
plt.xlabel('Slit Spacing [mm]', size=15)
plt.ylabel('Half-width [degrees]', size=15)
plt.title('How line-width changes with slit size',size=17)
plt.xticks(size=14)
plt.yticks(size=13)
#plt.savefig('line-width XRD.png')
plt.show()

# %%
half_width1 = np.abs(0.28519986-0.28592006)/N1
half_width2 = np.abs(0.16030573-0.16106499)/N2
half_width3 = np.abs(8.48362856e-02-8.54535695e-02)/N3
half_width4 = np.abs(7.75677735e-02-7.83542655e-02)/N4
half_width5 = np.abs(6.88055325e-02-7.00967304e-02)/N5
half_width6 = np.abs(6.20688284e-02-6.40768206e-02)/N6


from scipy.optimize import curve_fit

def linear_fit(x, a, b):
    return a*x + b

half_width_list = [half_width1, half_width2, half_width3, half_width4, half_width5, half_width6]
slit_list = [0.1, 0.2, 0.6, 1, 2, 6]
errors = 0.01*np.ones(6)


popt, pcov = curve_fit(linear_fit, slit_list, half_width_list, sigma=errors)
perr = np.sqrt(np.diag(pcov))


fig = plt.figure(figsize=(12,8))
plt.errorbar(slit_list, half_width_list, yerr = errors, fmt='.', color ='blue')
plt.xlabel('Slit Spacing [mm]', size=15)
plt.ylabel('Half-width [degrees]', size=15)
plt.title('How line-width changes with slit size',size=17)
plt.xticks(size=14)
plt.yticks(size=13)
#plt.savefig('new line-width XRD.png')
plt.show()

# %%
fig = plt.figure(figsize=(18,12))
plt.plot(data1[:,0],N6*data1[:,1], color='red', label='1mm, 0.1mm')
plt.plot(data2[:,0],N6*data2[:,1], color='orange', label='1mm, 0.2mm')
plt.plot(data7[:,0],N6*data7[:,1], color='green', label='2mm, 0.2mm')
plt.plot(data3[:,0],N6*data3[:,1], color='blue', label='1mm, 0.6mm')
plt.plot(data4[:,0],N6*data4[:,1], color='darkblue', label='1mm, 1mm')
plt.plot(data5[:,0],N6*data5[:,1], color='mediumorchid',label='1mm, 2mm')
plt.plot(data6[:,0],N6*data6[:,1], color='magenta', label='1mm, 6mm')
plt.title('Uniformly Normalised NaCl XRD using different slits', size=20)
plt.xlabel(r'$2\theta$ [degrees]',size=18)
plt.ylabel(r'$\frac{I}{I_{1}}$',size=30,rotation=0)
plt.xticks(size=14)
plt.yticks(size=13)
plt.xlim(31.1,32.4)
plt.legend(loc = 'upper left', prop={'size':16})
#plt.savefig('uniform different filters XRD.png')
plt.show()

# %%
mx1 = N6*np.max(data1[:,1])
mx2 = N6*np.max(data2[:,1])
mx3 = N6*np.max(data3[:,1])
mx4 = N6*np.max(data4[:,1])
mx5 = N6*np.max(data5[:,1])
mx6 = N6*np.max(data6[:,1])

max_intensities = [mx1,mx2,mx3,mx4,mx5,mx6]
slit_list = np.array([0.1, 0.2, 0.6, 1, 2, 6])

def log_fit(x, a, b):
    return np.log(x)*np.log(a) + b

popt, pcov = curve_fit(log_fit, slit_list, max_intensities, sigma=0.1*np.ones(6))
perr = np.sqrt(np.diag(pcov))
                       
fig = plt.figure(figsize=(12,8))
plt.scatter(slit_list, max_intensities)
plt.plot(np.linspace(0,6,101), log_fit(np.linspace(0,6,101), popt[0], popt[1]))           
plt.title('Uniformly Normalised NaCl XRD using different filters', size=20)
plt.xlabel(r'$2\theta$ [degrees]',size=18)
plt.ylabel(r'$\frac{I}{I_{1}}$',size=30,rotation=0)
plt.xticks(size=14)
plt.yticks(size=13)
#plt.savefig('uniform different filters XRD.png')
plt.show()

# %%
def exp_plat(x,k,YM,Y0):
     return YM -(YM-Y0)*np.exp(-k*x)
    
popt, pcov = curve_fit(exp_plat, slit_list, max_intensities, sigma=0.1*np.ones(6))
perr = np.sqrt(np.diag(pcov))

fig = plt.figure(figsize=(12,8))
plt.plot(slit_list, max_intensities, linestyle='none', marker='o',color='red', label='Data')
plt.plot(np.linspace(0,6,101), exp_plat(np.linspace(0,6,101), popt[0], popt[1],popt[2]),color='green'
         ,label=r'$I_{max} -  (I_{max}-I_0)e^{-kx}$')           
plt.title('How maximum amplitude varies with slit size', size=20)
plt.xlabel('Slit Spacing [mm]',size=18)
plt.ylabel('$I$',size=30,rotation=0)
plt.xticks(size=14)
plt.yticks(size=13)
plt.legend(loc = 'best', prop={'size':14})
#plt.savefig('amplitude graph.png')
plt.show()

print(popt)

# %% [markdown]
# ## How Ni filter effects the XRD graph

# %%
with open('/Users/guneraygin/Desktop/Y3 Labs/X-Ray Diffraction/Raw XRD Data/MnCO3 with Ni filter.txt') as f:
    lines = f.readlines()

lines = [line.replace(" ", '') for line in lines]
lines = [line.replace('\n','') for line in lines]
lines = [line.strip(',') for line in lines]
data = [line.split(',') for line in lines]

data = np.array(data)
data1 = data.astype(float) # with filter

N1 = 1/np.max(data1[:,1]) * 100

with open('/Users/guneraygin/Desktop/Y3 Labs/X-Ray Diffraction/Raw XRD Data/MnCO3 no Ni filter.txt') as f:
    lines = f.readlines()

lines = [line.replace(" ", '') for line in lines]
lines = [line.replace('\n','') for line in lines]
lines = [line.strip(',') for line in lines]
data = [line.split(',') for line in lines]

data = np.array(data)
data2 = data.astype(float) # without filter

N2 = 1/np.max(data2[:,1]) * 100

fig = plt.figure(figsize=(12,8))
plt.plot(data1[:,0],N1*data1[:,1], color='red',label='Nickel filter')
plt.plot(data2[:,0],N2*data2[:,1],color='blue',alpha=0.5,label='No filter')
plt.title('XRD Plot with and without a Ni filter', size=20)
plt.xlabel(r'$2\theta$ [degrees]',size=18)
plt.ylabel(r'$\frac{I}{I_{1}}$',size=30,rotation=0)
plt.xticks(size=14)
plt.yticks(size=13)
plt.text(28.2, 27.9, r'$K_{\beta}$', size=17, fontdict=None)
plt.text(40.4, 7, r'$K_{\beta}$', size=17, fontdict=None)
plt.legend(loc = 'best', prop={'size':14})
#plt.savefig('filter grpahs.png')
plt.show()

# %% [markdown]
# ## Actual Rhodochrosite?

# %%
with open('/Users/guneraygin/Desktop/Y3 Labs/X-Ray Diffraction/Raw XRD Data/rhodochrosite ground up.txt') as f:
    lines = f.readlines()

lines = [line.replace(" ", '') for line in lines]
lines = [line.replace('\n','') for line in lines]
lines = [line.strip(',') for line in lines]
data = [line.split(',') for line in lines]

data = np.array(data)
data = data.astype(float)

N = 1/np.max(data[:,1]) * 100

fig = plt.figure(figsize=(12,8))
plt.plot(data[:,0],N*data[:,1], color='deeppink')
plt.title('Unknown Mineral XRD', size=20)
plt.xlabel(r'$2\theta$ [degrees]',size=18)
plt.ylabel(r'$\frac{I}{I_{1}}$',size=30,rotation=0)
plt.xticks(size=14)
plt.yticks(size=13)
plt.savefig('Rhodochrosite graph.png')
plt.show()

# %%
data[420:450]

# %% [markdown]
# ## Actual CsCl

# %%
with open('/Users/guneraygin/Desktop/Y3 Labs/X-Ray Diffraction/Raw XRD Data/real CsCl.txt') as f:
    lines = f.readlines()

lines = [line.replace(" ", '') for line in lines]
lines = [line.replace('\n','') for line in lines]
lines = [line.strip(',') for line in lines]
data = [line.split(',') for line in lines]

data = np.array(data)
data = data.astype(float)

N = 1/np.max(data[:,1]) * 100

fig = plt.figure(figsize=(12,8))
plt.plot(data[:,0],N*data[:,1], color='red')
plt.title('CsCl XRD', size=20)
plt.xlabel(r'$2\theta$ [degrees]',size=18)
plt.ylabel(r'$\frac{I}{I_{1}}$',size=30,rotation=0)
plt.xticks(size=14)
plt.yticks(size=13)
plt.savefig('real CsCl.png')
plt.show()

# %%
data[600:700]
